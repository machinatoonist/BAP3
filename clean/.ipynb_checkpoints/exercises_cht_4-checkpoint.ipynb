# %%
import pymc as pm
import pandas as pd
import numpy as np
import arviz as az
import matplotlib.pyplot as plt
import preliz as pz

# %% [markdown]
# ## Exercise 1

# %%
howell_df = pd.read_csv("../code/data/howell.csv", sep=";")
howell_df.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
howell_df.shape
# Out:
# (544, 4)

# %%
howell_df = howell_df.query("age >= 18")

# %%
with pm.Model() as model_howell:
    # Priors
    alpha = pm.Normal('alpha', mu=0, sigma=10)
    beta = pm.Normal('beta', mu=0, sigma=10)
    sigma = pm.HalfNormal('sigma', sigma=10)

    # Expected value of outcome
    mu = alpha + beta * howell_df['weight']

    # Likelihood
    height_obs = pm.Normal('height_obs', mu=mu, sigma=sigma, observed=howell_df['height'])

    idata_howell = pm.sample(return_inferencedata=True)
    idata_howell.extend(pm.sample_posterior_predictive(idata_howell))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 6 seconds.
# Sampling: [height_obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
az.plot_trace(idata_howell, kind="rank_bars", figsize=(15,10), compact=True);

# %%
# Summary of the model
az.summary(idata_howell)
# Out:
#           mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  109.830  1.943  106.043  113.316      0.055    0.039    1235.0
# beta     0.993  0.043    0.918    1.079      0.001    0.001    1223.0
# sigma    5.136  0.203    4.743    5.499      0.005    0.003    1873.0
#
#        ess_tail  r_hat
# alpha    1585.0    1.0
# beta     1501.0    1.0
# sigma    1739.0    1.0

# %%
idata_howell
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> sample_stats
# 	> observed_data

# %%
az.plot_ppc(idata_howell, num_pp_samples=100);

# %% [markdown]
# # Exercise 2

# %%
import pymc as pm
import pandas as pd
import numpy as np
import arviz as az

# Load and filter the Howell dataset
howell_df = pd.read_csv("../code/data/howell.csv", sep=";")
howell_df = howell_df.query("age >= 18")

n_obs = len(howell_df['weight']) 

# Define the model
with pm.Model() as model_howell:
    # Priors
    alpha = pm.Normal('alpha', mu=0, sigma=10)
    beta = pm.Normal('beta', mu=0, sigma=10)
    sigma = pm.HalfNormal('sigma', sigma=10)
    
    # Use MutableData for weights
    weight = pm.MutableData('weight', howell_df['weight'])
    
    # Expected value of outcome
    mu = alpha + beta * weight
    
    # Likelihood
    height_obs = pm.Normal('height_obs', mu=mu, sigma=sigma, observed=howell_df['height'], shape = weight.shape)

# %%
pm.model_to_graphviz(model_howell)

# %%
with model_howell:
    idata_howell = pm.sample(return_inferencedata=True)
    idata_howell.extend(pm.sample_prior_predictive())
    idata_howell.extend(pm.sample_posterior_predictive(idata_howell))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 6 seconds.
# Sampling: [alpha, beta, height_obs, sigma]
# Sampling: [height_obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
az.plot_trace(idata_howell, kind="rank_bars");

# %%
new_weights = np.array([45.73, 65.8, 54.2, 32.59])

with model_howell:
    pm.set_data({'weight': new_weights})
    idata_howell = pm.sample_posterior_predictive(
        idata_howell, 
        predictions = True,
        extend_inferencedata= True
    )

# %%
idata_howell.
# Out:
# <xarray.Dataset>
# Dimensions:           (chain: 4, draw: 1000, height_obs_dim_2: 4)
# Coordinates:
#   * chain             (chain) int64 0 1 2 3
#   * draw              (draw) int64 0 1 2 3 4 5 6 ... 993 994 995 996 997 998 999
#   * height_obs_dim_2  (height_obs_dim_2) int64 0 1 2 3
# Data variables:
#     height_obs        (chain, draw, height_obs_dim_2) float64 158.1 ... 144.4
# Attributes:
#     created_at:                 2024-04-04T20:01:21.069056
#     arviz_version:              0.16.1
#     inference_library:          pymc
#     inference_library_version:  5.8.0

# %%
# Calculate HDIs for the new predictions
import arviz as az
predicted_heights = idata_howell.predictions["height_obs"]

hdi_50 = az.hdi(predicted_heights, hdi_prob=0.5)
hdi_94 = az.hdi(predicted_heights, hdi_prob=0.94)

# %%
# predicted_heights

# %%
idata_howell
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> predictions
# 	> sample_stats
# 	> prior
# 	> prior_predictive
# 	> observed_data
# 	> constant_data
# 	> predictions_constant_data

# %%
for i, weight in enumerate(new_weights):
    az.plot_posterior(idata_howell.predictions,
                      var_names=['height_obs'],
                      coords={'height_obs_dim_2': [i]},  
                      hdi_prob=0.94,
                      figsize=(10, 5))
    plt.title(f"Predicted Height Distribution for Weight: {weight}")
    plt.show()

# %%
import matplotlib.pyplot as plt

for i, weight in enumerate(new_weights):
    # Plotting the distribution with 94% HDI
    az.plot_posterior(idata_howell.predictions,
                      var_names=['height_obs'],
                      coords={'height_obs_dim_2': [i]},
                      hdi_prob=0.94,
                      figsize=(10, 5))
    
    # Calculate the 50% HDI separately
    hdi_50 = az.hdi(idata_howell.predictions['height_obs'].sel(height_obs_dim_2=i), hdi_prob=0.5)
    
    # Manually add the 50% HDI as a shaded area or vertical lines to the plot
    plt.fill_betweenx(y=[0, plt.gca().get_ylim()[1]],  # Adjust the y range appropriately
                      x1=hdi_50[0], x2=hdi_50[1],
                      color='gray', alpha=0.5)
    
    plt.title(f"Predicted Height Distribution for Weight: {weight}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, name)
#    1446             variable = self._variables[name]
#    1447         except KeyError:
# -> 1448             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1449
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_459/1828656735.py in ?()
#      12     hdi_50 = az.hdi(idata_howell.predictions['height_obs'].sel(height_obs_dim_2=i), hdi_prob=0.5)
#      13
#      14     # Manually add the 50% HDI as a shaded area or vertical lines to the plot
#      15     plt.fill_betweenx(y=[0, plt.gca().get_ylim()[1]],  # Adjust the y range appropriately
# ---> 16                       x1=hdi_50[0], x2=hdi_50[1],
#      17                       color='gray', alpha=0.5)
#      18
#      19     plt.title(f"Predicted Height Distribution for Weight: {weight}")
#
# ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, key)
#    1540         """
#    1541         if utils.is_dict_like(key):
#    1542             return self.isel(**key)
#    1543         if utils.hashable(key):
# -> 1544             return self._construct_dataarray(key)
#    1545         if utils.iterable_of_hashable(key):
#    1546             return self._copy_listed(key)
#    1547         raise ValueError(f"Unsupported key-type {type(key)}")
#
# ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, name)
#    1444
#    1445         try:
#    1446             variable = self._variables[name]
#    1447         except KeyError:
# -> 1448             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1449
#    1450         needed_dims = set(variable.dims)
#    1451
#
# ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     206         variable = IndexVariable((key,), data)
#     207         return key, key, variable
#     208
#     209     if not isinstance(key, str):
# --> 210         raise KeyError(key)
#     211
#     212     split_key = key.split(".", 1)
#     213     if len(split_key) != 2:
#
# KeyError: 0

# %%
az.plot_forest(idata_howell, var_names=["alpha", "beta"], combined = True, figsize=(10,4));

# %%
az.plot_hdi(idata_howell, hdi_data=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 az.plot_hdi(idata_howell)
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/arviz/plots/hdiplot.py:139, in plot_hdi(x, y, hdi_prob, hdi_data, color, circular, smooth, smooth_kwargs, figsize, fill_kwargs, plot_kwargs, hdi_kwargs, ax, backend, backend_kwargs, show)
#     136 x_shape = x.shape
#     138 if y is None and hdi_data is None:
# --> 139     raise ValueError("One of {y, hdi_data} is required")
#     140 if hdi_data is not None and y is not None:
#     141     warnings.warn("Both y and hdi_data arguments present, ignoring y")
#
# ValueError: One of {y, hdi_data} is required

# %%
import matplotlib.pyplot as plt

# Assuming predicted_heights contains the predicted values
for i, weight in enumerate(new_weights):
    # Extract the predicted heights for this particular weight
    preds = predicted_heights[:, i]  # Ensure it's a 1D array for calculations
    
    # Calculate the HDIs
    hdi_50 = az.hdi(preds, hdi_prob=0.5)
    hdi_94 = az.hdi(preds, hdi_prob=0.94)
    
    # Plot the distribution of predicted heights
    az.plot_posterior(preds, hdi_prob=0.94)
    plt.title(f"Predicted Height Distribution for Weight: {weight}")
    
    # Optionally, add HDI information as text
    plt.text(x=0.05, y=0.95, s=f"50% HDI: {hdi_50}\n94% HDI: {hdi_94}", transform=plt.gca().transAxes, verticalalignment='top')
    
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 9
#       6 preds = predicted_heights[:, i]  # Ensure it's a 1D array for calculations
#       8 # Calculate the HDIs
# ----> 9 hdi_50 = az.hdi(preds, hdi_prob=0.5)
#      10 hdi_94 = az.hdi(preds, hdi_prob=0.94)
#      12 # Plot the distribution of predicted heights
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/arviz/stats/stats.py:609, in hdi(ary, hdi_prob, circular, multimodal, skipna, group, var_names, filter_vars, coords, max_modes, dask_kwargs, **kwargs)
#     606 ary = ary[var_names] if var_names else ary
#     608 hdi_coord = xr.DataArray(["lower", "higher"], dims=["hdi"], attrs=dict(hdi_prob=hdi_prob))
# --> 609 hdi_data = _wrap_xarray_ufunc(
#     610     func, ary, func_kwargs=func_kwargs, dask_kwargs=dask_kwargs, **kwargs
#     611 ).assign_coords({"hdi": hdi_coord})
#     612 hdi_data = hdi_data.dropna("mode", how="all") if multimodal else hdi_data
#     613 return hdi_data.x.values if isarray else hdi_data
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/arviz/utils.py:750, in conditional_dask.<locals>.wrapper(*args, **kwargs)
#     746 @functools.wraps(func)
#     747 def wrapper(*args, **kwargs):
#     749     if not Dask.dask_flag:
# --> 750         return func(*args, **kwargs)
#     751     user_kwargs = kwargs.pop("dask_kwargs", None)
#     752     if user_kwargs is None:
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/arviz/stats/stats_utils.py:236, in wrap_xarray_ufunc(ufunc, ufunc_kwargs, func_args, func_kwargs, dask_kwargs, *datasets, **kwargs)
#     232 kwargs.setdefault("output_core_dims", tuple([] for _ in range(ufunc_kwargs.get("n_output", 1))))
#     234 callable_ufunc = make_ufunc(ufunc, **ufunc_kwargs)
# --> 236 return apply_ufunc(
#     237     callable_ufunc, *datasets, *func_args, kwargs=func_kwargs, **dask_kwargs, **kwargs
#     238 )
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/computation.py:1249, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1247 # feed datasets apply_variable_ufunc through apply_dataset_vfunc
#    1248 elif any(is_dict_like(a) for a in args):
# -> 1249     return apply_dataset_vfunc(
#    1250         variables_vfunc,
#    1251         *args,
#    1252         signature=signature,
#    1253         join=join,
#    1254         exclude_dims=exclude_dims,
#    1255         dataset_join=dataset_join,
#    1256         fill_value=dataset_fill_value,
#    1257         keep_attrs=keep_attrs,
#    1258         on_missing_core_dim=on_missing_core_dim,
#    1259     )
#    1260 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1261 elif any(isinstance(a, DataArray) for a in args):
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/computation.py:530, in apply_dataset_vfunc(func, signature, join, dataset_join, fill_value, exclude_dims, keep_attrs, on_missing_core_dim, *args)
#     525 list_of_coords, list_of_indexes = build_output_coords_and_indexes(
#     526     args, signature, exclude_dims, combine_attrs=keep_attrs
#     527 )
#     528 args = tuple(getattr(arg, "data_vars", arg) for arg in args)
# --> 530 result_vars = apply_dict_of_variables_vfunc(
#     531     func,
#     532     *args,
#     533     signature=signature,
#     534     join=dataset_join,
#     535     fill_value=fill_value,
#     536     on_missing_core_dim=on_missing_core_dim,
#     537 )
#     539 out: Dataset | tuple[Dataset, ...]
#     540 if signature.num_outputs > 1:
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/computation.py:457, in apply_dict_of_variables_vfunc(func, signature, join, fill_value, on_missing_core_dim, *args)
#     455 else:
#     456     if on_missing_core_dim == "raise":
# --> 457         raise ValueError(core_dim_present)
#     458     elif on_missing_core_dim == "copy":
#     459         result_vars[name] = variable_args[0]
#
# ValueError: Missing core dims {'draw'} from arg number 1 on a variable named `height_obs`:
# <xarray.Variable (chain: 4, height_obs_dim_2: 4)>
# array([[143.30399472, 168.0789823 , 158.656063  , 141.05801885],
#        [144.36701491, 189.21669334, 170.04751445, 138.73690528],
#        [163.44300022, 178.91617635, 167.33206629, 129.36657694],
#        [156.22660494, 177.04606466, 159.36976336, 140.86435472]])
#
# Either add the core dimension, or if passing a dataset alternatively pass `on_missing_core_dim` as `copy` or `drop`.

# %%
import matplotlib.pyplot as plt

# Extracting predicted heights from idata_howell
predicted_heights = idata_howell.predictions["height_obs"]

# Plotting the distribution of predicted heights for each new weight
for i, weight in enumerate(new_weights):
    az.plot_posterior(predicted_heights[:, i], hdi_prob=[0.5, 0.94])
    plt.title(f"Predicted Height Distribution for Weight: {weight}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 8
#       6 # Plotting the distribution of predicted heights for each new weight
#       7 for i, weight in enumerate(new_weights):
# ----> 8     az.plot_posterior(predicted_heights[:, i], hdi_prob=[0.5, 0.94])
#       9     plt.title(f"Predicted Height Distribution for Weight: {weight}")
#      10     plt.show()
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/arviz/plots/posteriorplot.py:241, in plot_posterior(data, var_names, filter_vars, combine_dims, transform, coords, grid, figsize, textsize, hdi_prob, multimodal, skipna, round_to, point_estimate, group, rope, ref_val, rope_color, ref_val_color, kind, bw, circular, bins, labeller, ax, backend, backend_kwargs, show, **kwargs)
#     239     hdi_prob = rcParams["stats.hdi_prob"]
#     240 elif hdi_prob not in (None, "hide"):
# --> 241     if not 1 >= hdi_prob > 0:
#     242         raise ValueError("The value of hdi_prob should be in the interval (0, 1]")
#     244 if point_estimate == "auto":
#
# TypeError: '>=' not supported between instances of 'int' and 'list'

# %%
# Calculate the 50% and 94% HDIs for the predicted heights
hdi_50 = az.hdi(predicted_heights, hdi_prob=0.5)
hdi_94 = az.hdi(predicted_heights, hdi_prob=0.94)

# Creating a summary DataFrame
hdi_summary = pd.DataFrame({
    'Weight': new_weights,
    '50% HDI Lower': hdi_50[:, 0],
    '50% HDI Upper': hdi_50[:, 1],
    '94% HDI Lower': hdi_94[:, 0],
    '94% HDI Upper': hdi_94[:, 1],
})

print(hdi_summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_459/3555221094.py in ?()
#       4
#       5 # Creating a summary DataFrame
#       6 hdi_summary = pd.DataFrame({
#       7     'Weight': new_weights,
# ----> 8     '50% HDI Lower': hdi_50[:, 0],
#       9     '50% HDI Upper': hdi_50[:, 1],
#      10     '94% HDI Lower': hdi_94[:, 0],
#      11     '94% HDI Upper': hdi_94[:, 1],
#
# ~/miniconda3/envs/bap3/lib/python3.11/site-packages/xarray/core/dataset.py in ?(self, key)
#    1543         if utils.hashable(key):
#    1544             return self._construct_dataarray(key)
#    1545         if utils.iterable_of_hashable(key):
#    1546             return self._copy_listed(key)
# -> 1547         raise ValueError(f"Unsupported key-type {type(key)}")
#
# ValueError: Unsupported key-type <class 'tuple'>

# %%
new_weights = np.array([45.73, 65.8, 54.2, 32.59])

with model_vv:
    pm.set_data({"weight": new_weights})
    ppc = pm.sample_posterior_predictive(idata_height, random_seed=123)
    y_ppc = ppc.posterior_predictive[""].stack(sample=("chain", "draw"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 new_weights = np.array([45.73, 65.8, 54.2, 32.59])
# ----> 3 with model_vv:
#       4     pm.set_data({"weight": new_weights})
#       5     ppc = pm.sample_posterior_predictive(idata_height, random_seed=123)
#
# NameError: name 'model_vv' is not defined

# %%
# Update the model with new weights
model_height['weight'].set_value(new_weights)

# Generate posterior predictive samples for new weights
with model_height:
    post_pred = pm.sample_posterior_predictive(idata_height, var_names=['height_obs'])
# Out:
# Sampling: [height_obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4000 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/compile/function/types.py:970, in Function.__call__(self, *args, **kwargs)
#     968 try:
#     969     outputs = (
# --> 970         self.vm()
#     971         if output_subset is None
#     972         else self.vm(output_subset=output_subset)
#     973     )
#     974 except Exception:
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/graph/op.py:552, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     548 @is_thunk_type
#     549 def rval(
#     550     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     551 ):
# --> 552     r = p(n, [x[0] for x in i], o)
#     553     for o in node.outputs:
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/tensor/random/op.py:333, in RandomVariable.perform(self, node, inputs, outputs)
#     331 rng_var_out[0] = rng
# --> 333 smpl_val = self.rng_fn(rng, *(args + [size]))
#     335 if (
#     336     not isinstance(smpl_val, np.ndarray)
#     337     or str(smpl_val.dtype) != out_var.type.dtype
#     338 ):
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/tensor/random/op.py:122, in RandomVariable.rng_fn(self, rng, *args, **kwargs)
#     121 """Sample a numeric random variate."""
# --> 122 return getattr(rng, self.name)(*args, **kwargs)
#
# File _generator.pyx:1146, in numpy.random._generator.Generator.normal()
#
# File _common.pyx:600, in numpy.random._common.cont()
#
# File _common.pyx:517, in numpy.random._common.cont_broadcast_2()
#
# File __init__.pxd:741, in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (352,) and arg 1 with shape (4,).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 8
#       6 # Generate posterior predictive samples for new weights
#       7 with model_height:
# ----> 8     post_pred = pm.sample_posterior_predictive(idata_height, var_names=['height_obs'])
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pymc/sampling/forward.py:644, in sample_posterior_predictive(trace, model, var_names, sample_dims, random_seed, progressbar, return_inferencedata, extend_inferencedata, predictions, idata_kwargs, compile_kwargs)
#     639 # there's only a single chain, but the index might hit it multiple times if
#     640 # the number of indices is greater than the length of the trace.
#     641 else:
#     642     param = _trace[idx % len_trace]
# --> 644 values = sampler_fn(**param)
#     646 for k, v in zip(vars_, values):
#     647     ppc_trace_t.insert(k.name, v, idx)
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pymc/util.py:391, in point_wrapper.<locals>.wrapped(**kwargs)
#     389 def wrapped(**kwargs):
#     390     input_point = {k: v for k, v in kwargs.items() if k in ins}
# --> 391     return core_function(**input_point)
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/compile/function/types.py:983, in Function.__call__(self, *args, **kwargs)
#     981     if hasattr(self.vm, "thunks"):
#     982         thunk = self.vm.thunks[self.vm.position_of_error]
# --> 983     raise_with_op(
#     984         self.maker.fgraph,
#     985         node=self.vm.nodes[self.vm.position_of_error],
#     986         thunk=thunk,
#     987         storage_map=getattr(self.vm, "storage_map", None),
#     988     )
#     989 else:
#     990     # old-style linkers raise their own exceptions
#     991     raise
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/link/utils.py:535, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     530     warnings.warn(
#     531         f"{exc_type} error does not allow us to add an extra error message"
#     532     )
#     533     # Some exception need extra parameter in inputs. So forget the
#     534     # extra long error message in that case.
# --> 535 raise exc_value.with_traceback(exc_trace)
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/compile/function/types.py:970, in Function.__call__(self, *args, **kwargs)
#     967 t0_fn = time.perf_counter()
#     968 try:
#     969     outputs = (
# --> 970         self.vm()
#     971         if output_subset is None
#     972         else self.vm(output_subset=output_subset)
#     973     )
#     974 except Exception:
#     975     restore_defaults()
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/graph/op.py:552, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     548 @is_thunk_type
#     549 def rval(
#     550     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     551 ):
# --> 552     r = p(n, [x[0] for x in i], o)
#     553     for o in node.outputs:
#     554         compute_map[o][0] = True
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/tensor/random/op.py:333, in RandomVariable.perform(self, node, inputs, outputs)
#     329     rng = copy(rng)
#     331 rng_var_out[0] = rng
# --> 333 smpl_val = self.rng_fn(rng, *(args + [size]))
#     335 if (
#     336     not isinstance(smpl_val, np.ndarray)
#     337     or str(smpl_val.dtype) != out_var.type.dtype
#     338 ):
#     339     smpl_val = _asarray(smpl_val, dtype=out_var.type.dtype)
#
# File ~/miniconda3/envs/bap3/lib/python3.11/site-packages/pytensor/tensor/random/op.py:122, in RandomVariable.rng_fn(self, rng, *args, **kwargs)
#     120 def rng_fn(self, rng, *args, **kwargs) -> Union[int, float, np.ndarray]:
#     121     """Sample a numeric random variate."""
# --> 122     return getattr(rng, self.name)(*args, **kwargs)
#
# File _generator.pyx:1146, in numpy.random._generator.Generator.normal()
#
# File _common.pyx:600, in numpy.random._common.cont()
#
# File _common.pyx:517, in numpy.random._common.cont_broadcast_2()
#
# File __init__.pxd:741, in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (352,) and arg 1 with shape (4,).
# Apply node that caused the error: normal_rv{0, (0, 0), floatX, True}(RandomGeneratorSharedVariable(<Generator(PCG64) at 0x7F776D085A80>), [352], 11, Composite{(i2 + (i0 * i1))}.0, sigma)
# Toposort index: 3
# Inputs types: [RandomGeneratorType, TensorType(int64, shape=(1,)), TensorType(int64, shape=()), TensorType(float64, shape=(None,)), TensorType(float64, shape=())]
# Inputs shapes: ['No shapes', (1,), (), (4,), ()]
# Inputs strides: ['No strides', (8,), (), (8,), ()]
# Inputs values: [Generator(PCG64) at 0x7F776D085A80, array([352]), array(11), array([155.60551307, 177.94140361, 165.03177081, 140.98201523]), array(5.11314416)]
# Outputs clients: [['output'], ['output']]
#
# HINT: Re-running with most PyTensor optimizations disabled could provide a back-trace showing when this node was created. This can be done by setting the PyTensor flag 'optimizer=fast_compile'. If that does not work, PyTensor optimizations can be disabled with 'optimizer=None'.
# HINT: Use the PyTensor flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
with model_vv:
    pm.set_data({"x_shared": [0.5]})
    ppc = pm.sample_posterior_predictive(idata_vv, random_seed=123)
    y_ppc = ppc.posterior_predictive["y_pred"].stack(sample=("chain", "draw"))
# Out:
# Sampling: [y_pred]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>
